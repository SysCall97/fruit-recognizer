# %% [markdown]
# **Objective:** The objective of this notebook is to infere the fruit recognizer model that we've built earlier. There are 12 categories of them. They are:
#  - Banana
#  - Coconut
#  - Guava
#  - Hog Plum
#  - Jackfruit
#  - Litchi
#  - Mango
#  - Papaya
#  - Starfruit
#  - Watermelon
#  - Wood Apple
#
#  You can find test images from this link: https://drive.google.com/drive/folders/1Y5MMCHZK1IJQnuMbZ1KzpvDcJJCqPmzE?usp=sharing

# %% [markdown]
# # **Setup:**

# %%
# !pip install -Uqq fastai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 29.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 15.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 36.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 37.1 MB/s eta 0:00:00

# %%
from fastai.vision.all import *

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/image_processing/fruit_recognizer
# Out:
# /content/drive/My Drive/image_processing/fruit_recognizer

# %%
version = 3
img_path = 'test_images'
model_path = f'models/fruit_recognizer_v{version}.pkl'

# %%
model = load_learner(model_path)

# %% [markdown]
# # **Inference - 1**

# %%
full_img_path = f'{img_path}/unknown_001.jpg'
img = Image.open(full_img_path)
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(full_img_path)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Mango',
#  tensor(6),
#  tensor([4.5071e-08, 3.2473e-07, 7.4421e-08, 1.1732e-08, 4.5212e-07, 8.5812e-07,
#          9.9972e-01, 2.7724e-04, 6.2415e-07, 1.8698e-07, 1.6866e-06]))

# %% [markdown]
# # **Inference - 2**

# %%
full_img_path = f'{img_path}/unknown_002.jpg'
img = Image.open(full_img_path)
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
model.predict(full_img_path)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Papaya',
#  tensor(7),
#  tensor([1.3664e-02, 6.8602e-04, 8.9790e-05, 1.4844e-03, 2.2956e-02, 1.2446e-02,
#          5.8855e-03, 9.1612e-01, 1.1999e-03, 1.3099e-03, 2.4157e-02]))

# %% [markdown]
# # **Inference - 3**

# %%
full_img_path = f'{img_path}/unknown_003.jpg'
img = Image.open(full_img_path)
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x72>

# %%
model.predict(full_img_path)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Coconut',
#  tensor(1),
#  tensor([4.2121e-04, 9.8753e-01, 1.0083e-04, 2.1737e-04, 1.3694e-03, 1.8489e-03,
#          1.6425e-03, 1.4502e-04, 3.6338e-03, 2.0230e-03, 1.0634e-03]))

# %% [markdown]
# # **Inference - 4**

# %%
full_img_path = f'{img_path}/unknown_004.jpg'
img = Image.open(full_img_path)
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(full_img_path)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Hog Plum',
#  tensor(3),
#  tensor([1.9536e-04, 5.0891e-02, 4.8227e-03, 7.6045e-01, 1.0129e-02, 3.3275e-02,
#          8.4606e-04, 3.2633e-03, 1.9982e-02, 1.2884e-02, 1.0326e-01]))
